# %%
import pandas as pd
import numpy as np

# %%
data = {
    'School Id': [101, 102, 103, np.nan, 105, 106, 107, 108],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank', 'Grace', 'Henry'],
    'Address': ['123 Main St', '456 Oak Ave', '789 Pine Ln', '101 Elm St', np.nan, '222 Maple Rd', '444 Cedar Blvd', '555 Birch Dr'],
    'City': ['Los Angeles', 'New York', 'Houston', 'Los Angeles', 'Miami', np.nan, 'Houston', 'New York'],
    'Subject': ['Math', 'English', 'Science', 'Math', 'History', 'Math', 'Science', 'English'],
    'Marks': [85, 92, 78, 89, np.nan, 95, 80, 88],
    'Rank': [2, 1, 4, 3, 8, 1, 5, 3],
    'Grade': ['B', 'A', 'C', 'B', 'D', 'A', 'C', 'B']
}

df = pd.DataFrame(data)
print("sample dataframe")
df
# Out:
# sample dataframe
#    School Id     Name         Address         City  Subject  Marks  Rank Grade
# 0      101.0    Alice     123 Main St  Los Angeles     Math   85.0     2     B
# 1      102.0      Bob     456 Oak Ave     New York  English   92.0     1     A
# 2      103.0  Charlie     789 Pine Ln      Houston  Science   78.0     4     C
# 3        NaN    David      101 Elm St  Los Angeles     Math   89.0     3     B
# 4      105.0      Eva             NaN        Miami  History    NaN     8     D
# 5      106.0    Frank    222 Maple Rd          NaN     Math   95.0     1     A
# 6      107.0    Grace  444 Cedar Blvd      Houston  Science   80.0     5     C
# 7      108.0    Henry    555 Birch Dr     New York  English   88.0     3     B

# %%
df.dropna()
# Out:
#    School Id     Name         Address         City  Subject  Marks  Rank Grade
# 0      101.0    Alice     123 Main St  Los Angeles     Math   85.0     2     B
# 1      102.0      Bob     456 Oak Ave     New York  English   92.0     1     A
# 2      103.0  Charlie     789 Pine Ln      Houston  Science   78.0     4     C
# 6      107.0    Grace  444 Cedar Blvd      Houston  Science   80.0     5     C
# 7      108.0    Henry    555 Birch Dr     New York  English   88.0     3     B

# %%
data = {
    'School Id': [101, 102, 103, np.nan, 105, 106, 107, 108],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank', 'Grace', 'Henry'],
    'Address': ['123 Main St', '456 Oak Ave', '789 Pine Ln', '101 Elm St', np.nan, '222 Maple Rd', '444 Cedar Blvd', '555 Birch Dr'],
    'City': ['Los Angeles', 'New York', 'Houston', 'Los Angeles', 'Miami', np.nan, 'Houston', 'New York'],
    'Subject': ['Math', 'English', 'Science', 'Math', 'History', 'Math', 'Science', 'English'],
    'Marks': [85, 92, 78, 89, np.nan, 95, 80, 88],
    'Rank': [2, 1, 4, 3, 8, 1, 5, 3],
    'Grade': ['B', 'A', 'C', 'B', 'D', 'A', 'C', 'B']
}

df = pd.DataFrame(data)
print("sample dataframe")
df
# Out:
# sample dataframe
#    School Id     Name         Address         City  Subject  Marks  Rank Grade
# 0      101.0    Alice     123 Main St  Los Angeles     Math   85.0     2     B
# 1      102.0      Bob     456 Oak Ave     New York  English   92.0     1     A
# 2      103.0  Charlie     789 Pine Ln      Houston  Science   78.0     4     C
# 3        NaN    David      101 Elm St  Los Angeles     Math   89.0     3     B
# 4      105.0      Eva             NaN        Miami  History    NaN     8     D
# 5      106.0    Frank    222 Maple Rd          NaN     Math   95.0     1     A
# 6      107.0    Grace  444 Cedar Blvd      Houston  Science   80.0     5     C
# 7      108.0    Henry    555 Birch Dr     New York  English   88.0     3     B

# %%
# mean median and mode imputation
# replacing missing value with mean, median or mode

mean_imputation = df['Marks'].fillna(df['Marks'].mean())
median_imputation = df['Marks'].fillna(df['Marks'].median())
mode_imputation = df['Marks'].fillna(df['Marks'].mode())

print('mean_imputation')
print(mean_imputation)
print('median_imputation')
print(median_imputation)
print('mode_imputation')
print(mode_imputation)
# Out:
# mean_imputation
# 0    85.000000
# 1    92.000000
# 2    78.000000
# 3    89.000000
# 4    86.714286
# 5    95.000000
# 6    80.000000
# 7    88.000000
# Name: Marks, dtype: float64
# median_imputation
# 0    85.0
# 1    92.0
# 2    78.0
# 3    89.0
# 4    88.0
# 5    95.0
# 6    80.0
# 7    88.0
# Name: Marks, dtype: float64
# mode_imputation
# 0    85.0
# 1    92.0
# 2    78.0
# 3    89.0
# 4    89.0
# 5    95.0
# 6    80.0
# 7    88.0
# Name: Marks, dtype: float64

# %%
# forward fill and backward fill
# forward fill uses previous fill value and vice versa

ffill = df['Marks'].fillna(method='ffill')
bfill = df['Marks'].fillna(method='bfill')

print('forward fill')
print(ffill)
print('backward fill')
print(bfill)
# Out:
# forward fill
# 0    85.0
# 1    92.0
# 2    78.0
# 3    89.0
# 4    89.0
# 5    95.0
# 6    80.0
# 7    88.0
# Name: Marks, dtype: float64
# backward fill
# 0    85.0
# 1    92.0
# 2    78.0
# 3    89.0
# 4    95.0
# 5    95.0
# 6    80.0
# 7    88.0
# Name: Marks, dtype: float64
# C:\Users\manth\AppData\Local\Temp\ipykernel_9764\2901288272.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ffill = df['Marks'].fillna(method='ffill')
# C:\Users\manth\AppData\Local\Temp\ipykernel_9764\2901288272.py:5: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   bfill = df['Marks'].fillna(method='bfill')

# %%
# linear interpolation and quadratic interpolation
# linear interpolation forms a straight line between two adjacent non-missing values
# quadratic interpolation forms a quadratic curve that passes through three non-adjacent values

linear_interpolation = df['Marks'].interpolate(method='linear')
quadratic_interpolation = df['Marks'].interpolate(method='quadratic')

print('linear interpolation')
print(linear_interpolation)
print('quadratic interpolation')
print(quadratic_interpolation)
# Out:
# linear interpolation
# 0    85.0
# 1    92.0
# 2    78.0
# 3    89.0
# 4    92.0
# 5    95.0
# 6    80.0
# 7    88.0
# Name: Marks, dtype: float64
# quadratic interpolation
# 0    85.00000
# 1    92.00000
# 2    78.00000
# 3    89.00000
# 4    98.28024
# 5    95.00000
# 6    80.00000
# 7    88.00000
# Name: Marks, dtype: float64
